# %%
import sys
import pandas as pd

sys.path.append(r"C:\Users\Baslael\Documents\Kifiya\week5\script")

from main import tokenize

df=pd.read_csv(r"C:\Users\Baslael\Documents\Kifiya\week5\telegram_data.csv")
df
# Out:
#             Channel Title    Channel Username    ID  \
# 0     Sheger online-store  @Shageronlinestore  5371
# 1     Sheger online-store  @Shageronlinestore  5370
# 2     Sheger online-store  @Shageronlinestore  5369
# 3     Sheger online-store  @Shageronlinestore  5368
# 4     Sheger online-store  @Shageronlinestore  5367
# ...                   ...                 ...   ...
# 1491  Sheger online-store  @Shageronlinestore  3768
# 1492  Sheger online-store  @Shageronlinestore  3767
# 1493  Sheger online-store  @Shageronlinestore  3766
# 1494  Sheger online-store  @Shageronlinestore  3765
# 1495  Sheger online-store  @Shageronlinestore  3764
#
#                                                 Message  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1491  💥  Broom  Holder\n🔰 የመጥረጊያ እና የተለያዩ ዕቃ መያዣ\n\n...
# 1492  💥  Broom  Holder\n🔰 የመጥረጊያ እና የተለያዩ ዕቃ መያዣ\n\n...
# 1493                                                NaN
# 1494                                                NaN
# 1495  💥  Broom  Holder\n🔰 የመጥረጊያ እና የተለያዩ ዕቃ መያዣ\n\n...
#
#                            Date                          Media Path
# 0     2024-09-26 09:20:41+00:00  photos\@Shageronlinestore_5371.jpg
# 1     2024-09-26 09:20:40+00:00  photos\@Shageronlinestore_5370.jpg
# 2     2024-09-26 09:20:40+00:00  photos\@Shageronlinestore_5369.jpg
# 3     2024-09-26 09:20:40+00:00  photos\@Shageronlinestore_5368.jpg
# 4     2024-09-26 09:20:40+00:00  photos\@Shageronlinestore_5367.jpg
# ...                         ...                                 ...
# 1491  2024-04-02 05:38:51+00:00                                 NaN
# 1492  2024-04-02 05:38:51+00:00                                 NaN
# 1493  2024-04-02 05:37:51+00:00  photos\@Shageronlinestore_3766.jpg
# 1494  2024-04-02 05:37:51+00:00  photos\@Shageronlinestore_3765.jpg
# 1495  2024-04-02 05:37:50+00:00  photos\@Shageronlinestore_3764.jpg
#
# [1496 rows x 6 columns]

# %%
df.isna().sum()
# Out:
# Channel Title         0
# Channel Username      0
# ID                    0
# Message             725
# Date                  0
# Media Path          253
# dtype: int64

# %%
df=df.dropna(subset=['Message'],axis=0)
df.isna().sum()
# Out:
# Channel Title         0
# Channel Username      0
# ID                    0
# Message               0
# Date                  0
# Media Path          248
# dtype: int64

# %%
df
# Out:
#             Channel Title    Channel Username    ID  \
# 5     Sheger online-store  @Shageronlinestore  5366
# 6     Sheger online-store  @Shageronlinestore  5365
# 9     Sheger online-store  @Shageronlinestore  5362
# 10    Sheger online-store  @Shageronlinestore  5361
# 16    Sheger online-store  @Shageronlinestore  5355
# ...                   ...                 ...   ...
# 1488  Sheger online-store  @Shageronlinestore  3771
# 1489  Sheger online-store  @Shageronlinestore  3770
# 1491  Sheger online-store  @Shageronlinestore  3768
# 1492  Sheger online-store  @Shageronlinestore  3767
# 1495  Sheger online-store  @Shageronlinestore  3764
#
#                                                 Message  \
# 5     💥SOKANY 3 in1 Blender /Grinder\n\nየጁስ የቡና የቅመም...
# 6     #አልቆል_ለተባላችሁ_በድጋሚ_አስገብተናል \n📣 IMPULSE SEALER\n...
# 9     💥 Feenik Vacuum Jug \n\n        💯 Hight Qulity...
# 10    💥Saachi®👚👔 አነስተኛ የልብስ  ማጠቢያ ማሽን👔\n\n👉 ለቲሸርት: ለ...
# 16    🌟4pcs travel squeeze bottle\n\n⚡️For:-shampoo,...
# ...                                                 ...
# 1488  💥waist trianer corset\n\n☛ቀሚስ ለመልበስ አስበዉ የቦርጭዎ...
# 1489  💥waist trianer corset\n\n☛ቀሚስ ለመልበስ አስበዉ የቦርጭዎ...
# 1491  💥  Broom  Holder\n🔰 የመጥረጊያ እና የተለያዩ ዕቃ መያዣ\n\n...
# 1492  💥  Broom  Holder\n🔰 የመጥረጊያ እና የተለያዩ ዕቃ መያዣ\n\n...
# 1495  💥  Broom  Holder\n🔰 የመጥረጊያ እና የተለያዩ ዕቃ መያዣ\n\n...
#
#                            Date                          Media Path
# 5     2024-09-26 09:20:40+00:00  photos\@Shageronlinestore_5366.jpg
# 6     2024-09-25 16:09:48+00:00  photos\@Shageronlinestore_5365.jpg
# 9     2024-09-25 05:48:37+00:00  photos\@Shageronlinestore_5362.jpg
# 10    2024-09-24 19:33:28+00:00  photos\@Shageronlinestore_5361.jpg
# 16    2024-09-24 12:57:53+00:00  photos\@Shageronlinestore_5355.jpg
# ...                         ...                                 ...
# 1488  2024-04-02 13:04:07+00:00  photos\@Shageronlinestore_3771.jpg
# 1489  2024-04-02 13:03:45+00:00  photos\@Shageronlinestore_3770.jpg
# 1491  2024-04-02 05:38:51+00:00                                 NaN
# 1492  2024-04-02 05:38:51+00:00                                 NaN
# 1495  2024-04-02 05:37:50+00:00  photos\@Shageronlinestore_3764.jpg
#
# [771 rows x 6 columns]

# %%
# def clean(row):
#     new_data=''
#     for a in list(row):
#             # if((ord(a)>=4608 and ord(a)<=4951) or (ord(a)>=48 and ord(a)<=57) or ord(a)==32): #with number
#             if((ord(a)>=4608 and ord(a)<=4951) or ord(a)==32):#without number
#                 new_data+=a
#     return new_data

# df['clean data']=df['Message'].apply(clean)

tokenize(df,'Message')
# Out:
# C:\Users\Baslael\Documents\Kifiya\week5\script\main.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['clean data']=df[col].apply(clean)
#             Channel Title    Channel Username    ID  \
# 5     Sheger online-store  @Shageronlinestore  5366
# 6     Sheger online-store  @Shageronlinestore  5365
# 9     Sheger online-store  @Shageronlinestore  5362
# 10    Sheger online-store  @Shageronlinestore  5361
# 16    Sheger online-store  @Shageronlinestore  5355
# ...                   ...                 ...   ...
# 1488  Sheger online-store  @Shageronlinestore  3771
# 1489  Sheger online-store  @Shageronlinestore  3770
# 1491  Sheger online-store  @Shageronlinestore  3768
# 1492  Sheger online-store  @Shageronlinestore  3767
# 1495  Sheger online-store  @Shageronlinestore  3764
#
#                                                 Message  \
# 5     💥SOKANY 3 in1 Blender /Grinder\n\nየጁስ የቡና የቅመም...
# 6     #አልቆል_ለተባላችሁ_በድጋሚ_አስገብተናል \n📣 IMPULSE SEALER\n...
# 9     💥 Feenik Vacuum Jug \n\n        💯 Hight Qulity...
# 10    💥Saachi®👚👔 አነስተኛ የልብስ  ማጠቢያ ማሽን👔\n\n👉 ለቲሸርት: ለ...
# 16    🌟4pcs travel squeeze bottle\n\n⚡️For:-shampoo,...
# ...                                                 ...
# 1488  💥waist trianer corset\n\n☛ቀሚስ ለመልበስ አስበዉ የቦርጭዎ...
# 1489  💥waist trianer corset\n\n☛ቀሚስ ለመልበስ አስበዉ የቦርጭዎ...
# 1491  💥  Broom  Holder\n🔰 የመጥረጊያ እና የተለያዩ ዕቃ መያዣ\n\n...
# 1492  💥  Broom  Holder\n🔰 የመጥረጊያ እና የተለያዩ ዕቃ መያዣ\n\n...
# 1495  💥  Broom  Holder\n🔰 የመጥረጊያ እና የተለያዩ ዕቃ መያዣ\n\n...
#
#                            Date                          Media Path  \
# 5     2024-09-26 09:20:40+00:00  photos\@Shageronlinestore_5366.jpg
# 6     2024-09-25 16:09:48+00:00  photos\@Shageronlinestore_5365.jpg
# 9     2024-09-25 05:48:37+00:00  photos\@Shageronlinestore_5362.jpg
# 10    2024-09-24 19:33:28+00:00  photos\@Shageronlinestore_5361.jpg
# 16    2024-09-24 12:57:53+00:00  photos\@Shageronlinestore_5355.jpg
# ...                         ...                                 ...
# 1488  2024-04-02 13:04:07+00:00  photos\@Shageronlinestore_3771.jpg
# 1489  2024-04-02 13:03:45+00:00  photos\@Shageronlinestore_3770.jpg
# 1491  2024-04-02 05:38:51+00:00                                 NaN
# 1492  2024-04-02 05:38:51+00:00                                 NaN
# 1495  2024-04-02 05:37:50+00:00  photos\@Shageronlinestore_3764.jpg
#
#                                              clean data
# 5     3 1 \nየጁስ የቡና የቅመም መፍጫ \n15 \n5 \n1000\n ከ 1 አ...
# 6     አልቆልለተባላችሁበድጋሚአስገብተናል \nየላስቲክ ማሸጊያ\n በኤሌክትሪክ የ...
# 9     ከጠንካራ የተሰራ\nለረጅም ሰአት ሙቀትን ጠብቆ ማቆየት የሚችል \n15 2...
# 10    አነስተኛ የልብስ ማጠቢያ ማሽን\n ለቲሸርት ለጂንስ ለሹራብለአንሶላ \nበ...
# 16    4 \n90\n ዋጋ600ብር\n አድራሻ መገናኛ ስሪ ኤም ሲቲ ሞል ሁለተኛ ...
# ...                                                 ...
# 1488  ቀሚስ ለመልበስ አስበዉ የቦርጭዎ ነገር አሳስቦዎታል\nቦርጭዎ ከተክለሰዉነ...
# 1489  ቀሚስ ለመልበስ አስበዉ የቦርጭዎ ነገር አሳስቦዎታል\nቦርጭዎ ከተክለሰዉነ...
# 1491  የመጥረጊያ እና የተለያዩ ዕቃ መያዣ\n ባለ አምስት መያዣ ያለው\n በድሪ...
# 1492  የመጥረጊያ እና የተለያዩ ዕቃ መያዣ\n ባለ አምስት መያዣ ያለው\n በድሪ...
# 1495  የመጥረጊያ እና የተለያዩ ዕቃ መያዣ\n ባለ አምስት መያዣ ያለው\n በድሪ...
#
# [771 rows x 7 columns]

# %%
# char='09'
# # char='ሀ ፗ'
# for a in list(char):
#     print(ord(a))
import string

tr=df.loc[5,'Message']
tr2=tr
tr2=tr2.translate(str.maketrans('','',string.punctuation))
tr,tr2,string.punctuation
# Out:
# ('💥SOKANY 3 in1 Blender /Grinder\n\nየጁስ የቡና የቅመም መፍጫ \n\n⚡️Sokany Blender with 1.5 liters of capacity.\n⚡️ Three pieces : Glass Blender , Plastic Blender and Chopper.\n⚡️ 5 speed function with high quality stainless steel blades.\n⚡️ 1000watt\n⚡️copper motor\n⚡️ice breaker\n⚡️ ከ 1 አመት ዋስትና ጋር\n\nዋጋ፦\xa0 💰 5300ብር\n\n\n\xa0\xa0\xa0 📲 0909522840\n\xa0\xa0\xa0 📲 0923350054\n\n\nአድራሻ\xa0 ቁ.1👉 ስሪ ኤም ሲቲ ሞል\xa0 ሁለተኛ ፎቅ ቢሮ ቁ. SL-05A(ከ ሊፍቱ ፊት ለ ፊት)\n\n📍ቁ.2 👉ለቡ\xa0 መዳህኒዓለም ቤተ/ክርስቲያን ፊት ለፊት\xa0 #ዛም_ሞል 2ኛ ፎቅ ቢሮ ቁጥር.214\n\n👍ለቡ\xa0ቅርንጫፍ📲0973611819\n\n🔖\n💬\xa0 በTelegram ለማዘዝ ⤵️ ይጠቀሙ\n@shager_onlinestore\n\xa0 \nለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️\nhttps://t.me/Shageronlinestore',
#  '💥SOKANY 3 in1 Blender Grinder\n\nየጁስ የቡና የቅመም መፍጫ \n\n⚡️Sokany Blender with 15 liters of capacity\n⚡️ Three pieces  Glass Blender  Plastic Blender and Chopper\n⚡️ 5 speed function with high quality stainless steel blades\n⚡️ 1000watt\n⚡️copper motor\n⚡️ice breaker\n⚡️ ከ 1 አመት ዋስትና ጋር\n\nዋጋ፦\xa0 💰 5300ብር\n\n\n\xa0\xa0\xa0 📲 0909522840\n\xa0\xa0\xa0 📲 0923350054\n\n\nአድራሻ\xa0 ቁ1👉 ስሪ ኤም ሲቲ ሞል\xa0 ሁለተኛ ፎቅ ቢሮ ቁ SL05Aከ ሊፍቱ ፊት ለ ፊት\n\n📍ቁ2 👉ለቡ\xa0 መዳህኒዓለም ቤተክርስቲያን ፊት ለፊት\xa0 ዛምሞል 2ኛ ፎቅ ቢሮ ቁጥር214\n\n👍ለቡ\xa0ቅርንጫፍ📲0973611819\n\n🔖\n💬\xa0 በTelegram ለማዘዝ ⤵️ ይጠቀሙ\nshageronlinestore\n\xa0 \nለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️\nhttpstmeShageronlinestore',
#  '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~')

# %%
import re
one_d=df.loc[5,"clean data"]
one_d
line=''
remain=''
if '\n' in one_d:
    line, remain=one_d.split('\n',1)
else:
    line, remain=one_d,""
print(f'line:{line}\n remain:{remain}')
# first=re.findall(r'\S',one_d)
# first
# Out:
# line:3 1
#  remain:የጁስ የቡና የቅመም መፍጫ
# 15
# 5
# 1000
#  ከ 1 አመት ዋስትና ጋር
# ዋጋ 5300ብር
#  0909522840
#  0923350054
# አድራሻ ቁ1 ስሪ ኤም ሲቲ ሞል ሁለተኛ ፎቅ ቢሮ ቁ 05ከ ሊፍቱ ፊት ለ ፊት
# ቁ2 ለቡ መዳህኒዓለም ቤተክርስቲያን ፊት ለፊት ዛምሞል 2ኛ ፎቅ ቢሮ ቁጥር214
# ለቡቅርንጫፍ0973611819
#  በ ለማዘዝ ይጠቀሙ
#  ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን
