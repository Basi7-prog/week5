# %%
import sys
import pandas as pd

sys.path.append(r"C:\Users\Baslael\Documents\Kifiya\week5\script")

from main import tokenize,clean_repeatitive_words

df=pd.read_csv(r"C:\Users\Baslael\Documents\Kifiya\week5\telegram_data@modernshoppingcenter.csv")
df
# Out:
#                               Channel Title       Channel Username    ID  \
# 0     ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  4604
# 1     ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  4603
# 2     ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  4602
# 3     ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  4601
# 4     ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  4600
# ...                                     ...                    ...   ...
# 4068  ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter     8
# 4069  ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter     6
# 4070  ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter     5
# 4071  ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter     4
# 4072  ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter     1
#
#                                                 Message  \
# ...

# %%
df.isna().sum()
# Out:
# Channel Title          0
# Channel Username       0
# ID                     0
# Message             2565
# Date                   0
# Media Path           557
# dtype: int64

# %%
df=df.dropna(subset=['Message'],axis=0)
df.isna().sum()
# Out:
# Channel Title         0
# Channel Username      0
# ID                    0
# Message               0
# Date                  0
# Media Path          127
# dtype: int64

# %%
df
# Out:
#                               Channel Title       Channel Username    ID  \
# 2     ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  4602
# 5     ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  4599
# 7     ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  4597
# 10    ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  4594
# 14    ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  4590
# ...                                     ...                    ...   ...
# 4065  ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter    11
# 4067  ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter     9
# 4068  ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter     8
# 4069  ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter     6
# 4070  ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter     5
#
#                                                 Message  \
# ...

# %%
# def clean(row):
#     new_data=''
#     for a in list(row):
#             # if((ord(a)>=4608 and ord(a)<=4951) or (ord(a)>=48 and ord(a)<=57) or ord(a)==32): #with number
#             if((ord(a)>=4608 and ord(a)<=4951) or ord(a)==32):#without number
#                 new_data+=a
#     return new_data

# df['clean data']=df['Message'].apply(clean)

tokenize(df,'Message')
# Out:
# C:\Users\Baslael\Documents\Kifiya\week5\script\main.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['clean data']=df[col].apply(clean)
#                               Channel Title       Channel Username    ID  \
# 2     ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  4602
# 5     ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  4599
# 7     ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  4597
# 10    ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  4594
# 14    ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  4590
# ...                                     ...                    ...   ...
# 4065  ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter    11
# ...

# %%
# char='09'
# # char='ሀ ፗ'
# for a in list(char):
#     print(ord(a))
import string

tr=df.loc[3973,'Message']
tr2=tr
tr2=tr2.translate(str.maketrans('','',string.punctuation))
tr,tr2,string.punctuation
# Out:
# ('ኳሊቲ የቡና ማፈያ(coffee Maker)\nየራሱ የሙቀት መቆጣጠሪያ ያለዉ\nለአያያዝና ለአጠቃቀም በጣም ምቹ\nለቤት፣ለቢሮናለስራቦታ አመቺ\n6 ሲኒ ቡና የሚይዝ\nበ 1800ብር። \nአድራሻ=ጉርድ ሾላ ከቴሌዉ በተቃራኒ ከአዲስ ቤቲ ካፌ ጎን። \n0911454907\n🎺የተለያዩ እቃዎችን ለማየትና ለማዘዝ ከታች ባለዉ የቴሌግራም ቻናላችን ይመልከቱ። \nt.me//hbg11',
#  'ኳሊቲ የቡና ማፈያcoffee Maker\nየራሱ የሙቀት መቆጣጠሪያ ያለዉ\nለአያያዝና ለአጠቃቀም በጣም ምቹ\nለቤት፣ለቢሮናለስራቦታ አመቺ\n6 ሲኒ ቡና የሚይዝ\nበ 1800ብር። \nአድራሻጉርድ ሾላ ከቴሌዉ በተቃራኒ ከአዲስ ቤቲ ካፌ ጎን። \n0911454907\n🎺የተለያዩ እቃዎችን ለማየትና ለማዘዝ ከታች ባለዉ የቴሌግራም ቻናላችን ይመልከቱ። \ntmehbg11',
#  '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~')

# %%
import re
one_d=df.loc[2,"clean data"]
one_d
line=''
remain=''
if '\n' in one_d:
    line, remain=one_d.split('\n',1)
else:
    line, remain=one_d,""
print(f'line:{line}\n remain:{remain}')
# first=re.findall(r'\S',one_d)
# first
remains=remain.split('\n')
# Out:
# line:ቴሌግራም
#  remain: በአዲስ ነገረ ሁሌም ቀዳሚዏች ነን
# የሊጥ መዳመጫ ምንጣፎ እና ሮለር
# ምንጣፉ ሊጥ የማይዝ የማይንሸራተት እና ልኬት ቁጥር ያለው ሲልከን ጎማ
#  መዳመጫ ሩሎው ሊጥ የማይዝ ሲልከን ጎማ ያለው
# 360 በራሱ የሚሽከረከር
#  በትልቁ መጠን የቀረበ
# ለአጠቃቀም ቀላል
# ሁለቱንም በአንድ ላይ በ
#  1600
# 0924743736
# 0974978584
# በስራችን ላይ ቅሬታ ካለዎት ብቻ በዚህ ስልክ ደዉለዉ ያሳዉቁን
# 0956415152
# የመረጡትን እቃ ለማዘዝ ከታች ባለዉ የቴሌግራም አድራሻ ይላኩልን
# 1
#  2
# አዲስ አበባ ዉስጥ ከ100ብር እስከ 200ብር ብቻ በማስከፈል ያሉበት ድረስ በፈጣን ሞተረኞቻችን እንልክልዏታለን
# አድራሻቁጥር 1 ጉርድሾላ ከሴንቸሪ ሞል ትንሽ ዝቅ እንዳሉ ሆሊሲቲ ሴንተር ላይ እንደገቡ ፊትለፊት ከሊፍቱ በግራ በኩል ሚዛን ላይ 06
#  ቁጥር 2 ጀሞ መስታወትፋብሪካ ፊትለፊት ራሐ ሞል ግራዉንድ ፍሎር ከደረጃዉ ጎን
# በሞደርን እቃወዏች ሂወትዎን
#  ሞደርናይዝ ያድርጉ

# %%
clean_repeatitive_words(df,'clean data')
df
# Out:
# C:\Users\Baslael\Documents\Kifiya\week5\script\main.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col]=df[col].str.replace(pattern,'', regex=True)
#                               Channel Title       Channel Username    ID  \
# 2     ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  4602
# 5     ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  4599
# 7     ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  4597
# 10    ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  4594
# 14    ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  4590
# ...                                     ...                    ...   ...
# ...
